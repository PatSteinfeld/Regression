# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/bundesliga_points.csv')

# %%
data.head()
# Out:
#    2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    77    75    70    76    69    70    75    81    91    90    79    88
# 1    63    70    68    66    67    65    68    73    66    71    69    78
# 2    59    68    66    64    64    61    65    64    65    64    66    60
# 3    58    61    60    54    63    59    60    60    55    61    61    55
# 4    58    52    51    54    61    57    58    54    51    60    49    52
#
#    2016  2017  2018
# 0    82    84    78
# 1    67    63    76
# 2    64    55    66
# 3    62    55    58
# 4    49    55    55

# %%
data.plot(kind='scatter',x='2004',y='2016')
# Out:
# <AxesSubplot:xlabel='2004', ylabel='2016'>

# %%
sns.pairplot(data, plot_kws=dict(alpha=.1, edgecolor='none'))

# %%
sns.regplot(x = '2004', y = '2016', data=data)
# Out:
# <AxesSubplot:xlabel='2004', ylabel='2016'>

# %%
sns.regplot(x = '2004', y = '2018', data=data)
# Out:
# <AxesSubplot:xlabel='2004', ylabel='2018'>

# %%
data1 = pd.read_csv('/content/laliga_points.csv')

# %%
data2 = pd.read_csv('/content/premierleague_points.csv')

# %%
data3 = pd.read_csv('/content/seriea_points.csv')

# %%
data1
# Out:
#     2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0     84    82    76    85    87    99    96   100   100    90    94    91
# 1     80    70    76    77    78    96    92    91    85    87    92    90
# 2     65    69    71    67    70    71    71    61    76    87    78    88
# 3     62    68    66    64    67    63    62    58    66    70    77    64
# 4     61    68    62    64    65    62    58    56    65    63    76    62
# 5     60    64    60    60    62    58    58    55    57    59    60    60
# 6     58    57    60    59    58    56    58    54    56    59    55    52
# 7     51    55    54    52    55    54    49    52    53    49    51    48
# 8     51    54    52    52    51    47    47    50    50    49    50    48
# 9     50    52    50    51    47    47    47    49    47    48    49    45
# 10    50    46    49    50    46    44    46    47    46    45    49    44
# ...

# %%
data2
# Out:
#     2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0     95    91    89    87    90    86    80    89    89    86    87    81
# 1     83    83    83    85    86    85    71    89    78    84    79    71
# 2     77    82    68    83    83    75    71    70    75    82    75    70
# 3     61    67    68    76    72    70    68    69    73    79    70    66
# 4     58    65    60    65    63    67    62    65    72    72    64    66
# 5     58    63    58    60    62    64    58    64    63    69    62    63
# 6     55    58    56    58    53    63    54    56    61    64    60    62
# 7     52    56    55    57    51    61    49    52    49    56    56    60
# 8     52    55    54    55    51    50    48    52    46    50    54    51
# 9     47    51    52    49    50    50    47    47    46    49    48    50
# 10    46    50    50    46    45    47    47    47    44    45    47    47
# ...

# %%
data3
# Out:
#     2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0     86    76    97    85    84    82    82    84    87   102    87    91
# 1     79    69    75    82    74    80    76    80    78    85    70    82
# 2     72    58    62    72    74    70    70    64    72    78    69    80
# 3     62    54    61    66    68    67    66    62    70    65    64    67
# 4     61    52    58    64    68    65    66    61    66    60    63    64
# 5     53    49    58    60    63    59    63    58    62    58    59    61
# 6     48    45    54    57    58    55    58    56    61    57    56    57
# 7     45    45    50    50    57    52    56    56    56    57    55    54
# 8     45    44    49    48    53    51    51    51    54    56    54    50
# 9     44    43    46    48    50    50    51    49    49    54    52    46
# 10    44    43    43    47    47    47    46    48    47    50    49    46
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
x1 = np.random.normal(0, 1, 100)
y1 = 2*x1 + np.random.normal(0, 1, 100)
x2 = np.random.normal(0, 1, 100)
y2 = 3*x2 + np.random.normal(0, 1, 100)

# Create a scatter plot of the data
plt.scatter(x1, y1, label='Dataset 1')
plt.scatter(x2, y2, label='Dataset 2')

# Calculate the regression line for each dataset
slope1, intercept1 = np.polyfit(x1, y1, 1)
slope2, intercept2 = np.polyfit(x2, y2, 1)

# Plot the regression lines
plt.plot(x1, slope1*x1 + intercept1, color='blue', label='Regression line 1')
plt.plot(x2, slope2*x2 + intercept2, color='orange', label='Regression line 2')

# Add a legend and axis labels
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')

# Display the plot
plt.show()

# %%
sns.regplot(x = '2004', y = '2018', data=data1)
sns.regplot(x = '2004', y = '2018', data=data2)
sns.regplot(x = '2004', y = '2018', data=data3)
# Out:
# <AxesSubplot:xlabel='2004', ylabel='2018'>

# %%
sns.regplot(x = '2004', y = '2018', data=data)
sns.regplot(x = '2004', y = '2018', data=data1)
sns.regplot(x = '2004', y = '2018', data=data2)
sns.regplot(x = '2004', y = '2018', data=data3)
# Out:
# <AxesSubplot:xlabel='2004', ylabel='2018'>
